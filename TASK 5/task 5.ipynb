# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv(r'C:\Users\Lenovo\Desktop\data analyst internship\TASK  5\train.csv')

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
print(df.head())
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
print(df.describe())
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
print(df.describe(include=['O']))
# Out:
#                            Name   Sex  Ticket    Cabin Embarked
# count                       891   891     891      204      889
# unique                      891     2     681      147        3
# top     Braund, Mr. Owen Harris  male  347082  B96 B98        S
# freq                          1   577       7        4      644

# %%
print(df.isnull().sum())
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
vc=df['Sex'].value_counts()

# %%
vc
# Out:
# Sex
# male      577
# female    314
# Name: count, dtype: int64

# %%
print(df['Embarked'].value_counts())
# Out:
# Embarked
# S    644
# C    168
# Q     77
# Name: count, dtype: int64

# %%
print(df['Survived'].value_counts())
# Out:
# Survived
# 0    549
# 1    342
# Name: count, dtype: int64

# %%
selected_columns = ['Survived', 'Pclass', 'Age', 'Fare'] # Select a few important columns

# %%
sns.pairplot(df[selected_columns], hue='Survived', palette='coolwarm' )  # Create the pairplot
plt.show()

# %% [markdown]
#  ## 1. Survived vs Age:
#
# A slightly higher survival rate is observed in younger passengers (children and teens).
# Very young children (ages 0–10) show a stronger presence of red dots (survivors).

# %% [markdown]
#  ## 2. Survived vs Fare:
#
# Red dots (survivors) are more densely packed in the higher Fare range.
# Most blue dots (non-survivors) are clustered around low fare values.

# %%
# Sex vs Survival
sns.countplot(x='Sex', hue='Survived', data=df)
plt.title('Survival Count by Sex')
plt.show()

# %%
# Histogram of Age
plt.figure(figsize=(8,5))
sns.histplot(df['Age'], bins=30, kde=True)  # kde=True gives smooth curve
plt.title('Distribution of Age')
plt.xlabel('Age')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# ## Observation: Distribution of Age
# Overall Shape:
# The age distribution follows a right-skewed bell-shaped curve, which is common in human population data.
# The majority of passengers were between 20 and 40 years old

# %%
# Boxplot of Fare by Pclass
plt.figure(figsize=(8,5))
sns.boxplot(x='Pclass', y='Fare', data=df)
plt.title('Fare by Passenger Class')
plt.xlabel('Passenger Class')
plt.ylabel('Fare')
plt.show()

# %% [markdown]
# ## Observation: Fare by Passenger Class (Boxplot)
#  1. Fare Distribution Across Classes:
# Pclass 1 (First Class):
# Has the highest median fare.
# Shows a wide range of fares, including many high-value outliers (some fares exceed 500 units).
# Indicates significant variability in luxury pricing within this class.
#
# Pclass 2 (Second Class):
# Has a moderate median fare, significantly lower than Pclass 1.
# Narrower spread of fares compared to Pclass 1.
# Few or no extreme outliers.
#
# Pclass 3 (Third Class):
# Has the lowest median fare.
# Most fares are tightly packed at the lower end (below 50 units).
# A few outliers are present, showing some 3rd-class passengers paid more—possibly for special accommodations.

# %%
# Scatterplot Age vs Fare
plt.figure(figsize=(8,5))
sns.scatterplot(x='Age', y='Fare', data=df)
plt.title('Age vs Fare')
plt.xlabel('Age')
plt.ylabel('Fare')
plt.show()

# %% [markdown]
# ##  Observation: Scatterplot – Age vs Fare
# 1. General Distribution:
# The plot is sparse and unevenly distributed, with most data points concentrated in the lower fare range (0–100).
# Passengers of all ages paid fares in that lower range, indicating that fare was not strictly dependent on age.
#
# 2. High Fare Outliers:
# A few passengers (regardless of age) paid extremely high fares (above 300), indicating they may have had premium accommodations, most likely in first class.
# These high-fare outliers are scattered from young to elderly ages.
#
# 3. Dense Region:
# A dense cluster appears where:
# Age is between 20–40
# Fare is between 0–50
# This suggests most passengers were young to middle-aged adults and paid lower fares, likely indicating third-class passengers.
#
# 4. Children and Fare:
# Some younger children (under 10 years) are also seen with moderate to high fares, possibly traveling with family in higher classes.
